# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import numpy as np

# %%
df=pd.read_csv('cardio_train.csv',sep=';')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y=df.iloc[:,12]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
fit_features=SelectKBest(score_func=f_classif)

# %%
fit_features.fit(x,y)
# Out:
# SelectKBest()

# %%
score_culom=pd.DataFrame(fit_features.scores_,
columns=['score_value'])

# %%
score_culom
# Out:
#     score_value
# 0      1.010461
# 1   4209.007957
# 2      4.603641
# 3      8.197397
# 4   2388.777887
# 5    208.339524
# 6    303.629011
# 7   3599.361137
# 8    562.772977
# 9     16.790541
# 10     3.761355
# 11    89.091494

# %%
name_col=pd.DataFrame(x.columns)

# %%
top_features=pd.concat([name_col,score_culom],axis=1)

# %%
top_features
# Out:
#               0  score_value
# 0            id     1.010461
# 1           age  4209.007957
# 2        gender     4.603641
# 3        height     8.197397
# 4        weight  2388.777887
# 5         ap_hi   208.339524
# 6         ap_lo   303.629011
# 7   cholesterol  3599.361137
# 8          gluc   562.772977
# 9         smoke    16.790541
# 10         alco     3.761355
# 11       active    89.091494

# %%
top_features.nlargest(8,'score_value')
# Out:
#               0  score_value
# 1           age  4209.007957
# 7   cholesterol  3599.361137
# 4        weight  2388.777887
# 8          gluc   562.772977
# 6         ap_lo   303.629011
# 5         ap_hi   208.339524
# 11       active    89.091494
# 9         smoke    16.790541

# %%
dff=df.drop(['id','gender','alco','height','smoke'], axis=1)

# %%
dff
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  active  cardio
# 0      18393    62.0    110     80            1     1       1       0
# 1      20228    85.0    140     90            3     1       1       1
# 2      18857    64.0    130     70            3     1       0       1
# 3      17623    82.0    150    100            1     1       1       1
# 4      17474    56.0    100     60            1     1       0       0
# ...      ...     ...    ...    ...          ...   ...     ...     ...
# 69995  19240    76.0    120     80            1     1       1       0
# 69996  22601   126.0    140     90            2     2       1       1
# 69997  19066   105.0    180     90            3     1       0       1
# 69998  22431    72.0    135     80            1     2       0       1
# 69999  20540    72.0    120     80            2     1       1       0
#
# [70000 rows x 8 columns]

# %%
x=dff.iloc[:,:-1]

# %%
x
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  active
# 0      18393    62.0    110     80            1     1       1
# 1      20228    85.0    140     90            3     1       1
# 2      18857    64.0    130     70            3     1       0
# 3      17623    82.0    150    100            1     1       1
# 4      17474    56.0    100     60            1     1       0
# ...      ...     ...    ...    ...          ...   ...     ...
# 69995  19240    76.0    120     80            1     1       1
# 69996  22601   126.0    140     90            2     2       1
# 69997  19066   105.0    180     90            3     1       0
# 69998  22431    72.0    135     80            1     2       0
# 69999  20540    72.0    120     80            2     1       1
#
# [70000 rows x 7 columns]

# %%
y=dff.iloc[:,7]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20,random_state=42)

# %%
xtrain
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  active
# 47339  21876    80.0    130     90            2     1       1
# 67456  16717    70.0    140     90            1     1       0
# 12308  21128    92.0    150    100            1     1       1
# 32557  23366    76.0    120     82            1     1       1
# 664    20281    60.0    120     80            1     1       1
# ...      ...     ...    ...    ...          ...   ...     ...
# 37194  16001    75.0    150     80            1     1       1
# 6265   23209    73.0    160     90            1     1       1
# 54886  23589    74.0    120     80            1     1       1
# 860    18227    70.0    120     80            1     1       0
# 15795  15114    64.0    120     80            1     1       1
#
# [56000 rows x 7 columns]

# %%
ytrain
# Out:
# 47339    1
# 67456    1
# 12308    1
# 32557    1
# 664      0
#         ..
# 37194    1
# 6265     1
# 54886    0
# 860      0
# 15795    0
# Name: cardio, Length: 56000, dtype: int64

# %%
xtest
# Out:
#          age  weight  ap_hi  ap_lo  cholesterol  gluc  active
# 46730  21770    64.0    140     80            2     1       1
# 48393  21876    85.0    160     90            1     1       1
# 41416  23270    90.0    130     80            1     1       1
# 34506  19741    97.0    120     80            1     1       1
# 43725  18395    68.0    120     80            1     1       1
# ...      ...     ...    ...    ...          ...   ...     ...
# 21525  20490    70.0    120     80            1     1       0
# 16276  16797    96.0    120     80            1     2       1
# 24390  22607    66.0    110     80            1     1       0
# 28061  19670    89.0    120     80            3     3       1
# 63452  18320    83.0    140     90            1     1       0
#
# [14000 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rclf=RandomForestClassifier()

# %%
rclf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rclf.score(xtest,ytest)
# Out:
# 0.6890714285714286

# %%
pred=rclf.predict(xtest)

# %%
pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,pred)
# Out:
# 0.6890714285714286

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(ytest,pred)
# Out:
# array([[4742, 2246],
#        [2107, 4905]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ytest,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.68      0.69      6988
#            1       0.69      0.70      0.69      7012
#
#     accuracy                           0.69     14000
#    macro avg       0.69      0.69      0.69     14000
# weighted avg       0.69      0.69      0.69     14000

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
from sklearn.model_selection import cross_val_score

# %%
result=cross_val_score(model,x,y,cv=20)

# %%
print(result)
# Out:
# [0.63628571 0.62885714 0.63457143 0.63114286 0.64257143 0.64457143
#  0.63142857 0.646      0.63828571 0.61971429 0.62942857 0.64485714
#  0.624      0.64657143 0.646      0.64142857 0.64114286 0.63342857
#  0.624      0.64542857]

# %%
result.mean()
# Out:
# 0.6364857142857143
